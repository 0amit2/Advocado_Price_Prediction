# %% [markdown]
# # **Avocado_Price_Prediction**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
import zipfile
zip=zipfile.ZipFile('/content/drive/MyDrive/Data Science/Project/Advocado.zip')
zip.extractall()
zip.close()

# %%
df=pd.read_csv('/content/avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.shape
# Out:
# (18249, 14)

# %%
df=df.sort_values('Date')

# %%
df.head()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046      4225  \
# 11569          51  2015-01-04          1.75      27365.89  9307.34   3844.81
# 9593           51  2015-01-04          1.49      17723.17  1189.35  15628.27
# 10009          51  2015-01-04          1.68       2896.72   161.68    206.96
# 1819           51  2015-01-04          1.52      54956.80  3013.04  35456.88
# 9333           51  2015-01-04          1.64       1505.12     1.27   1129.50
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 11569   615.28    13598.46    13061.10      537.36          0.0       organic
# 9593      0.00      905.55      905.55        0.00          0.0       organic
# 10009     0.00     2528.08     2528.08        0.00          0.0       organic
# 1819   1561.70    14925.18    11264.80     3660.38          0.0  conventional
# 9333      0.00      374.35      186.67      187.68          0.0       organic
#
#        year              region
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(df['Date'],df['AveragePrice'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='region',palette='husl')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(df,x='year',palette='husl')
plt.show()

# %%
df_advocado=df[['Date','AveragePrice']]

# %%
df_advocado.head()
# Out:
#              Date  AveragePrice
# 11569  2015-01-04          1.75
# 9593   2015-01-04          1.49
# 10009  2015-01-04          1.68
# 1819   2015-01-04          1.52
# 9333   2015-01-04          1.64

# %%
df_advocado.tail()
# Out:
#              Date  AveragePrice
# 8574   2018-03-25          1.36
# 9018   2018-03-25          0.70
# 18141  2018-03-25          1.42
# 17673  2018-03-25          1.70
# 8814   2018-03-25          1.34

# %% [markdown]
# **Make Prediction**

# %%
df_final=df_advocado.rename(columns={'Date':'ds','AveragePrice':'y'})

# %%
df_final
# Out:
#                ds     y
# 11569  2015-01-04  1.75
# 9593   2015-01-04  1.49
# 10009  2015-01-04  1.68
# 1819   2015-01-04  1.52
# 9333   2015-01-04  1.64
# ...           ...   ...
# 8574   2018-03-25  1.36
# 9018   2018-03-25  0.70
# 18141  2018-03-25  1.42
# 17673  2018-03-25  1.70
# 8814   2018-03-25  1.34
#
# [18249 rows x 2 columns]

# %%
from prophet import Prophet
m=Prophet()
m.fit(df_final)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# forecast the future
future=m.make_future_dataframe(periods=365)
forecast=m.predict(future)

# %%
forecast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.501457    0.914356    1.861400     1.501457     1.501457
# 1   2015-01-11  1.496063    0.895178    1.866140     1.496063     1.496063
# 2   2015-01-18  1.490670    0.898260    1.849052     1.490670     1.490670
# 3   2015-01-25  1.485277    0.843041    1.827643     1.485277     1.485277
# 4   2015-02-01  1.479883    0.806249    1.816902     1.479883     1.479883
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.157867    0.568548    1.606024     0.947961     1.358352
# 530 2019-03-22  1.157123    0.552816    1.598401     0.945977     1.358605
# 531 2019-03-23  1.156378    0.530189    1.601761     0.944404     1.358857
# 532 2019-03-24  1.155633    0.544646    1.580480     0.943078     1.359110
# 533 2019-03-25  1.154889    0.554146    1.580154     0.941767     1.359362
#
# ...

# %%
figure=m.plot(forecast,xlabel='Date',ylabel='Price',figsize=(10,5))

# %%
figure=m.plot_components(forecast)

# %% [markdown]
# # **Region-wise prediction**

# %%
df['region'].unique()
# Out:
# array(['Southeast', 'Chicago', 'HarrisburgScranton', 'Pittsburgh',
#        'Boise', 'WestTexNewMexico', 'LosAngeles', 'LasVegas', 'Atlanta',
#        'DallasFtWorth', 'MiamiFtLauderdale', 'Plains', 'StLouis',
#        'Syracuse', 'Midsouth', 'Sacramento', 'Boston', 'Charlotte',
#        'Spokane', 'Albany', 'Houston', 'SouthCarolina', 'SanFrancisco',
#        'TotalUS', 'RaleighGreensboro', 'BuffaloRochester',
#        'NorthernNewEngland', 'GrandRapids', 'Denver', 'SanDiego',
#        'BaltimoreWashington', 'Roanoke', 'RichmondNorfolk', 'Northeast',
#        'SouthCentral', 'GreatLakes', 'Louisville', 'Seattle',
#        'CincinnatiDayton', 'NewYork', 'NewOrleansMobile', 'Indianapolis',
#        'Jacksonville', 'Columbus', 'Detroit', 'Philadelphia',
#        'PhoenixTucson', 'Nashville', 'Portland', 'HartfordSpringfield',
#        'Tampa', 'Orlando', 'West', 'California'], dtype=object)

# %%
df_sample=df[df['region']=='West']

# %%
df_sample
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11881          51  2015-01-04          1.40     187548.30    70313.71
# 2755           51  2015-01-04          0.89    5794410.58  2275446.87
# 11880          50  2015-01-11          1.39     223156.55    80139.16
# 2754           50  2015-01-11          0.95    5333097.71  2203111.92
# 2753           49  2015-01-18          0.96    5475363.01  2431736.63
# ...           ...         ...           ...           ...         ...
# 9104            2  2018-03-11          1.00    6906412.50  2442241.76
# 18226           1  2018-03-18          1.73     210067.47    33437.98
# 9103            1  2018-03-18          0.99    7254940.65  2099082.66
# 9102            0  2018-03-25          0.93    7667064.46  2567279.74
# 18225           0  2018-03-25          1.60     271723.08    26996.28
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.plot(df_sample['Date'],df_sample['AveragePrice'])

# %%
df_sample=df_sample.rename(columns={'Date':'ds','AveragePrice':'y'})

# %%
from prophet import Prophet
m=Prophet()
m.fit(df_sample)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
futrue=m.make_future_dataframe(periods=365)
forecast=m.predict(future)

# %%
figure=m.plot(forecast,xlabel='Date',ylabel="Price",figsize=(10,5))

# %%
figure=m.plot_components(forecast)
